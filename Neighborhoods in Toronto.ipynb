# %% [markdown]
# # Section 1

# %% [markdown]
# #### Import libraries

# %%
import requests
import bs4
import lxml.html as lh
import pandas as pd
pd.set_option('display.max_rows',300)
import folium

# %%
res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

# %%
#Store the contents of the website under doc
doc = lh.fromstring(res.content)

# %%
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
#Check the length of the first 12 rows
[len(T) for T in tr_elements[:12]]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
#Parse Table Header

tr_elements = doc.xpath('//tr')

# %%
#Create empty list
col=[]
i=0

#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"' %(i,name))
    col.append((name,[]))
# Out:
# 1:"Postcode"
# 2:"Borough"
# 3:"Neighbourhood
# "

# %%
print(col)
# Out:
# [('Postcode', []), ('Borough', []), ('Neighbourhood\n', [])]

# %%
#Since out first row is the header, data is stored on the second row onwards

for j in range(1,len(tr_elements)):
    
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
print(col)
# Out:
# [('Postcode', ['M1A', 'M2A', 'M3A', 'M4A', 'M5A', 'M5A', 'M6A', 'M6A', 'M7A', 'M8A', 'M9A', 'M1B', 'M1B', 'M2B', 'M3B', 'M4B', 'M4B', 'M5B', 'M5B', 'M6B', 'M7B', 'M8B', 'M9B', 'M9B', 'M9B', 'M9B', 'M9B', 'M1C', 'M1C', 'M1C', 'M2C', 'M3C', 'M3C', 'M4C', 'M5C', 'M6C', 'M7C', 'M8C', 'M9C', 'M9C', 'M9C', 'M9C', 'M1E', 'M1E', 'M1E', 'M2E', 'M3E', 'M4E', 'M5E', 'M6E', 'M7E', 'M8E', 'M9E', 'M1G', 'M2G', 'M3G', 'M4G', 'M5G', 'M6G', 'M7G', 'M8G', 'M9G', 'M1H', 'M2H', 'M3H', 'M3H', 'M3H', 'M4H', 'M5H', 'M5H', 'M5H', 'M6H', 'M6H', 'M7H', 'M8H', 'M9H', 'M1J', 'M2J', 'M2J', 'M2J', 'M3J', 'M3J', 'M4J', 'M5J', 'M5J', 'M5J', 'M6J', 'M6J', 'M7J', 'M8J', 'M9J', 'M1K', 'M1K', 'M1K', 'M2K', 'M3K', 'M3K', 'M4K', 'M4K', 'M5K', 'M5K', 'M6K', 'M6K', 'M6K', 'M7K', 'M8K', 'M9K', 'M1L', 'M1L', 'M1L', 'M2L', 'M2L', 'M3L', 'M4L', 'M4L', 'M5L', 'M5L', 'M6L', 'M6L', 'M6L', 'M7L', 'M8L', 'M9L', 'M1M', 'M1M', 'M1M', 'M2M', 'M2M', 'M3M', 'M4M', 'M5M', 'M5M', 'M6M', 'M6M', 'M6M', 'M6M', 'M7M', 'M8M', 'M9M', 'M9M', 'M1
# ...

# %%
[len(C) for (title,C) in col]
# Out:
# [288, 288, 288]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood\n
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n

# %%
df.tail()
# Out:
#     Postcode       Borough          Neighbourhood\n
# 283      M8Z     Etobicoke              Mimico NW\n
# 284      M8Z     Etobicoke     The Queensway West\n
# 285      M8Z     Etobicoke  Royal York South West\n
# 286      M8Z     Etobicoke         South of Bloor\n
# 287      M9Z  Not assigned           Not assigned\n

# %%
df.shape
# Out:
# (288, 3)

# %% [markdown]
# #### Data cleaning

# %%
df.Borough.str.contains("Not assigned")
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 258     True
# 259     True
# 260     True
# 261     True
# 262    False
# 263     True
# 264     True
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# 270    False
# 271    False
# 272    False
# 273    False
# 274     True
# 275     True
# 276     True
# 277     True
# 278     True
# 279     True
# 280     True
# 281     True
# 282    False
# 283    False
# 284    False
# 285    False
# 286    False
# 287     True
# Name: Borough, Length: 288, dtype: bool

# %%
df1 = df[~df.Borough.str.contains("Not assigned")]

# %%
df1.shape
# Out:
# (211, 3)

# %%
df1
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# ...

# %%
#trying out remove \n
df1['Neighbourhood\n'].replace('\n','',regex=True)
# Out:
# 2                                              Parkwoods
# 3                                       Victoria Village
# 4                                           Harbourfront
# 5                                            Regent Park
# 6                                       Lawrence Heights
# 7                                         Lawrence Manor
# 8                                           Not assigned
# 10                                      Islington Avenue
# 11                                                 Rouge
# 12                                               Malvern
# 14                                       Don Mills North
# 15                                      Woodbine Gardens
# 16                                         Parkview Hill
# 17                                               Ryerson
# 18                                       Garden District
# 19                                             Glencairn
# ...

# %%
df1
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# ...

# %%
df1 = df1.replace(r'\n',' ', regex=True)

# %%
df1
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# ...

# %%
df2 = df1.copy()  #save a copy first

# %%
df2
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# ...

# %%
df2.columns
# Out:
# Index(['Postcode', 'Borough', 'Neighbourhood\n'], dtype='object')

# %%
df2.rename(columns= lambda x: x.strip(), inplace=True)

# %%
df2.columns
# Out:
# Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')

# %%
df2.head()  #Stripped \n
# Out:
#   Postcode           Borough      Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %%
df2.shape
# Out:
# (211, 3)

# %%
df2.columns
# Out:
# Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')

# %%
df3 = df2.groupby(['Postcode','Borough'], as_index=False).agg(','.join)

# %%
df3.head()
# Out:
#   Postcode      Borough                            Neighbourhood
# 0      M1B  Scarborough                          Rouge ,Malvern
# 1      M1C  Scarborough  Highland Creek ,Rouge Hill ,Port Union
# 2      M1E  Scarborough       Guildwood ,Morningside ,West Hill
# 3      M1G  Scarborough                                  Woburn
# 4      M1H  Scarborough                               Cedarbrae

# %%
df3   #See and check all rows
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
print("The number of rows of the dataframe:", df3.shape)
# Out:
# The number of rows of the dataframe: (103, 3)

# %%
#df3.to_csv('cleaned.csv',index=False) #save a csv file

# %% [markdown]
# # Part 2

# %%
#Import the geospatial data

geodata = pd.read_csv('Geospatial_Coordinates.csv')

# %%
geodata.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
df4 = df3.merge(geodata, how="left", on="Postcode")

# %% [markdown]
# ### Dataframe for Q2 is below:

# %%
df4
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# # Part 3

# %%
latitude = 43.636966
longitude = -79.615819

# %%
# create map of Mississauga using latitude and longitude values
map = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <img src="map1.jpg">

# %%
#Define markers

tooltip = 'Click me!'

folium.Marker([latitude,longitude], popup='<b>Canada Post Gateway Processing Centre</b>', tooltip=tooltip).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <img src="map2.jpg">

# %% [markdown]
# #### Note: There is no nearby neighbourhood for Mississauga
